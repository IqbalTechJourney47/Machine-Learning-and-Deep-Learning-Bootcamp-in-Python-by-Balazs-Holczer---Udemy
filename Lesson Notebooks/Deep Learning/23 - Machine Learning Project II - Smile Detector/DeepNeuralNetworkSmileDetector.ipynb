# %%
# train_folder = '/kaggle/input/smiledetection/datasets/train_folder/'
# test_folder = '/kaggle/input/smiledetection/datasets/test_folder/'

# %%
# pip install pillow

# %%
from PIL import Image
import os
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
directory = 'training_set/'

# %%
# [
#     [0, 10, 25, ..., 100, 150, 200, ...],  # Pixel intensities for the first image
#     [255, 245, 230, ..., 155, 105, 50, ...],  # Pixel intensities for the second image
# ]

# %% [markdown]
# You open the image using the PIL (Pillow) library's Image.open method.
# .convert('1') converts the image to grayscale using a single channel, meaning that each pixel value represents the intensity of the gray color.
#
#
# pixel_intensities.append(list(image.getdata())):
#
# You're extracting the pixel intensities from the resized grayscale image using the .getdata() method. This method returns a sequence of pixel values as a 1D tuple.
#
# list(image.getdata()) converts the tuple of pixel values into a list and appends it to the pixel_intensities list.

# %%
# Define a common image size
common_image_size = (32, 32)  # Adjust as needed

pixel_intensities = [] # 1D array, List to store resized pixel intensities

# one-hot encoding: happy (1,0) and sad (0,1)
labels = []

for filename in os.listdir(directory):
    # print(filename)
    image = Image.open(directory+filename).convert('1')
    # image = Image.open(os.path.join(directory, filename)).convert('L')  # Convert to grayscale
    image = image.resize(common_image_size)  # Resize the image to a common size
    # print(image)
    
    pixel_intensities.append(list(image.getdata()))
    # print(image.getdata())
    
    # pixel_intensities.append(np.array(image).flatten())  # Convert to numpy array and flatten
    # print(np.array(image).flatten())
    
    # print(pixel_intensities) # Pixel intensities for the first image, for the second image and so on.
    
    # print(list(image.getdata())) # converts the tuple of pixel values into a list and appends it to the pixel_intensities list
    
    if filename[0:5] == 'happy': # [0:5] - first 5 characters
        labels.append([1, 0])
    elif filename[0:3] == 'sad':
        labels.append([0, 1])
        
    #if filename.startswith('happy'):
    #    labels.append([1, 0])
    #elif filename.startswith('sad'):
    #    labels.append([0, 1])

pixel_intensities = np.array(pixel_intensities)
# print(pixel_intensities)   # it returns 1D array containing sub-arrays
                            # where every single sub-array or every single row in the dataset is going to represent
                            # a given image with pixel_intensities
                            # 32*32 images
                            # 1024 items in a given sub-array=
                    
# print(pixel_intensities.shape) # it returns (30, 1024) ) (6, 640000) 6 is the size of the dataset

labels = np.array(labels)
# print(labels.shape) # it returns (30, 2) 30 samples in the dataset, 2 columns/value happy(1,0) and sad(0,1)
# print(labels) # it retuens a 1D array with sub-arrays
                # every single sub-array is going to represent the label associated with a given face
    
labels = np.array(labels)

# Now pixel_intensities will be a 2D array with consistent shape, suitable for training


# In this modified code, images are resized to a common size (common_image_size) before converting them to numpy arrays.
# The images are converted to grayscale using the 'L' mode for simplicity.
# The pixel intensities are flattened into a 1D array using flatten(), and then the processed data is used to create
# the numpy arrays pixel_intensities and labels.

# %% [markdown]
# for filename in os.listdir(directory):
#
#     print(filename)
#
# If i print out the filename and run the algorithm, then python is going to iterate through as far this training set
# directory is concerned and it is going to print out the name of the file.
#
#
#
# These are images so somehow we have to parse these images.
#
# With the help of the image, we can open directory plus the file.
#
#
# for filename in os.listdir(directory):
#
#     # print(filename)
#
#     image = Image.open(directory+filename).convert('1')
#
#
#
# We are going to append/open the file in the directory and in the first iteration, we are going to use:
#
#
# directory = 'training_set/386.jpg'
#
# directory = 'training_set/663.jpg'
#
# directory = 'training_set/46.jpg'
#
#
# In every iteration, we are going to consider some other image and we would like to convert to binary.

# %% [markdown]
# image = Image.open(directory+filename).convert('1')
#
# convert('1')
#
# it means we are not going to deal with red, green, blue channels. The image is going to be grayscale which means that every single pixel intensity is going to be within 0(black pixel) upto 255(white pixel).

# %% [markdown]
# pixel_intensities.append(list(image.getdata()))
#     # print(image.getdata())
#
# Here, we are going to transform this ImagingCore into a list

# %% [markdown]
# # Min-Max Normalization

# %%
# apply min-max normalization (here just /255)
# transformation of values within the range 0 and 1

pixel_intensities = pixel_intensities / 255.0

# print(pixel_intensities)

# %% [markdown]
# # Building the deep neural network model

# %%
# Create the model (deep neural networks)
model = Sequential()
model.add(Dense(1024, input_dim=1024, activation='relu')) # input layer
model.add(Dense(512, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='softmax')) # output layer

learning_rate = 0.005
optimizer = Adam(learning_rate=learning_rate)
model.compile(loss='categorical_crossentropy',
             optimizer=optimizer,
             metrics=['accuracy'])

model.fit(pixel_intensities, labels, epochs=1000, batch_size=20, verbose=2) # pixel_intensities, as far as the features are concerned
# Out:
# Epoch 1/1000
# 2/2 - 1s - loss: 7.7189 - accuracy: 0.4667 - 903ms/epoch - 451ms/step
# Epoch 2/1000
# 2/2 - 0s - loss: 1.7944 - accuracy: 0.6667 - 62ms/epoch - 31ms/step
# Epoch 3/1000
# 2/2 - 0s - loss: 1.7184 - accuracy: 0.6000 - 63ms/epoch - 31ms/step
# Epoch 4/1000
# 2/2 - 0s - loss: 1.0756 - accuracy: 0.6000 - 60ms/epoch - 30ms/step
# Epoch 5/1000
# 2/2 - 0s - loss: 1.0362 - accuracy: 0.4333 - 65ms/epoch - 32ms/step
# Epoch 6/1000
# 2/2 - 0s - loss: 0.6247 - accuracy: 0.6667 - 59ms/epoch - 29ms/step
# Epoch 7/1000
# 2/2 - 0s - loss: 0.7036 - accuracy: 0.5667 - 59ms/epoch - 29ms/step
# Epoch 8/1000
# 2/2 - 0s - loss: 0.6042 - accuracy: 0.6667 - 61ms/epoch - 30ms/step
# Epoch 9/1000
# 2/2 - 0s - loss: 0.5383 - accuracy: 0.8000 - 69ms/epoch - 34ms/step
# Epoch 10/1000
# 2/2 - 0s - loss: 0.5204 - accuracy: 0.6667 - 69ms/epoch - 34ms/step
# Epoch 11/1000
# 2/2 - 0s - loss: 0.5095 - accuracy: 0.7000 - 60ms/epoch - 30ms/step
# Epoch 12/1000
# 2/2 - 0s - loss: 0.4453 - accuracy: 0.8000 - 58ms/epoch - 29ms/step
# Epoch 13/1000
# 2/2 - 0s - loss: 0.4923 - accuracy: 0.8000 - 64ms/epoch - 32ms/step
# Epoch 14/1000
# 2/2 - 0s - loss: 0.5877 - accuracy: 0.6667 - 61ms/epoch - 30ms/step
# Epoch 15/1000
# 2/2 - 0s - loss: 0.3818 - accuracy: 0.8333 - 60ms/epoch - 30ms/step
# Epoch 16/1000
# 2/2 - 0s - loss: 0.3520 - accuracy: 0.7667 - 59ms/epoch - 29ms/step
# Epoch 17/1000
# 2/2 - 0s - loss: 0.1696 - accuracy: 0.9333 - 57ms/epoch - 28ms/step
# Epoch 18/1000
# 2/2 - 0s - loss: 0.1609 - accuracy: 0.9000 - 65ms/epoch - 32ms/step
# Epoch 19/1000
# 2/2 - 0s - loss: 0.0691 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 20/1000
# 2/2 - 0s - loss: 0.0592 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 21/1000
# 2/2 - 0s - loss: 0.0206 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 22/1000
# 2/2 - 0s - loss: 0.0145 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 23/1000
# 2/2 - 0s - loss: 0.0016 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 24/1000
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 25/1000
# 2/2 - 0s - loss: 0.0027 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 26/1000
# 2/2 - 0s - loss: 0.0016 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 27/1000
# 2/2 - 0s - loss: 7.9981e-04 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 28/1000
# 2/2 - 0s - loss: 2.1952e-04 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 29/1000
# 2/2 - 0s - loss: 6.9042e-05 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 30/1000
# 2/2 - 0s - loss: 3.3717e-05 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 31/1000
# 2/2 - 0s - loss: 1.6557e-05 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 32/1000
# 2/2 - 0s - loss: 1.0204e-05 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 33/1000
# 2/2 - 0s - loss: 6.6438e-06 - accuracy: 1.0000 - 72ms/epoch - 36ms/step
# Epoch 34/1000
# 2/2 - 0s - loss: 5.5312e-06 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 35/1000
# 2/2 - 0s - loss: 4.4703e-06 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 36/1000
# 2/2 - 0s - loss: 4.2517e-06 - accuracy: 1.0000 - 69ms/epoch - 34ms/step
# Epoch 37/1000
# 2/2 - 0s - loss: 3.9656e-06 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 38/1000
# 2/2 - 0s - loss: 3.6438e-06 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 39/1000
# 2/2 - 0s - loss: 3.4133e-06 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 40/1000
# 2/2 - 0s - loss: 3.1471e-06 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 41/1000
# 2/2 - 0s - loss: 2.9444e-06 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 42/1000
# 2/2 - 0s - loss: 2.7815e-06 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 43/1000
# 2/2 - 0s - loss: 2.5749e-06 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 44/1000
# 2/2 - 0s - loss: 2.4477e-06 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 45/1000
# 2/2 - 0s - loss: 2.3087e-06 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 46/1000
# 2/2 - 0s - loss: 2.2133e-06 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 47/1000
# 2/2 - 0s - loss: 2.1060e-06 - accuracy: 1.0000 - 81ms/epoch - 40ms/step
# Epoch 48/1000
# 2/2 - 0s - loss: 2.0305e-06 - accuracy: 1.0000 - 74ms/epoch - 37ms/step
# Epoch 49/1000
# 2/2 - 0s - loss: 1.9312e-06 - accuracy: 1.0000 - 84ms/epoch - 42ms/step
# Epoch 50/1000
# 2/2 - 0s - loss: 1.8755e-06 - accuracy: 1.0000 - 84ms/epoch - 42ms/step
# Epoch 51/1000
# 2/2 - 0s - loss: 1.8120e-06 - accuracy: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 52/1000
# 2/2 - 0s - loss: 1.7365e-06 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 53/1000
# 2/2 - 0s - loss: 1.6689e-06 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 54/1000
# 2/2 - 0s - loss: 1.6173e-06 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 55/1000
# 2/2 - 0s - loss: 1.5815e-06 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 56/1000
# 2/2 - 0s - loss: 1.5338e-06 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 57/1000
# 2/2 - 0s - loss: 1.5020e-06 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 58/1000
# 2/2 - 0s - loss: 1.4742e-06 - accuracy: 1.0000 - 80ms/epoch - 40ms/step
# Epoch 59/1000
# 2/2 - 0s - loss: 1.4543e-06 - accuracy: 1.0000 - 71ms/epoch - 35ms/step
# Epoch 60/1000
# 2/2 - 0s - loss: 1.4146e-06 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 61/1000
# 2/2 - 0s - loss: 1.3908e-06 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 62/1000
# 2/2 - 0s - loss: 1.3590e-06 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 63/1000
# 2/2 - 0s - loss: 1.3351e-06 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 64/1000
# 2/2 - 0s - loss: 1.3153e-06 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 65/1000
# 2/2 - 0s - loss: 1.3073e-06 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 66/1000
# 2/2 - 0s - loss: 1.2835e-06 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 67/1000
# 2/2 - 0s - loss: 1.2676e-06 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 68/1000
# 2/2 - 0s - loss: 1.2358e-06 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 69/1000
# 2/2 - 0s - loss: 1.2239e-06 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 70/1000
# 2/2 - 0s - loss: 1.2080e-06 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 71/1000
# 2/2 - 0s - loss: 1.1921e-06 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 72/1000
# 2/2 - 0s - loss: 1.1722e-06 - accuracy: 1.0000 - 72ms/epoch - 36ms/step
# Epoch 73/1000
# 2/2 - 0s - loss: 1.1643e-06 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 74/1000
# 2/2 - 0s - loss: 1.1444e-06 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 75/1000
# 2/2 - 0s - loss: 1.1245e-06 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 76/1000
# 2/2 - 0s - loss: 1.1086e-06 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 77/1000
# 2/2 - 0s - loss: 1.0967e-06 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 78/1000
# 2/2 - 0s - loss: 1.0967e-06 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 79/1000
# 2/2 - 0s - loss: 1.0729e-06 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 80/1000
# 2/2 - 0s - loss: 1.0689e-06 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 81/1000
# 2/2 - 0s - loss: 1.0530e-06 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 82/1000
# 2/2 - 0s - loss: 1.0451e-06 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 83/1000
# 2/2 - 0s - loss: 1.0292e-06 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 84/1000
# 2/2 - 0s - loss: 1.0133e-06 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 85/1000
# 2/2 - 0s - loss: 1.0093e-06 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 86/1000
# 2/2 - 0s - loss: 9.8943e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 87/1000
# 2/2 - 0s - loss: 9.7354e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 88/1000
# 2/2 - 0s - loss: 9.6559e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 89/1000
# 2/2 - 0s - loss: 9.5764e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 90/1000
# 2/2 - 0s - loss: 9.4970e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 91/1000
# 2/2 - 0s - loss: 9.4175e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 92/1000
# 2/2 - 0s - loss: 9.3380e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 93/1000
# 2/2 - 0s - loss: 9.2585e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 94/1000
# 2/2 - 0s - loss: 9.2188e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 95/1000
# 2/2 - 0s - loss: 9.0599e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 96/1000
# 2/2 - 0s - loss: 8.9804e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 97/1000
# 2/2 - 0s - loss: 8.7817e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 98/1000
# 2/2 - 0s - loss: 8.7420e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 99/1000
# 2/2 - 0s - loss: 8.6625e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 100/1000
# 2/2 - 0s - loss: 8.6228e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 101/1000
# 2/2 - 0s - loss: 8.5830e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 102/1000
# 2/2 - 0s - loss: 8.4241e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 103/1000
# 2/2 - 0s - loss: 8.4241e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 104/1000
# 2/2 - 0s - loss: 8.3446e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 105/1000
# 2/2 - 0s - loss: 8.2254e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 106/1000
# 2/2 - 0s - loss: 8.1459e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 107/1000
# 2/2 - 0s - loss: 8.1062e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 108/1000
# 2/2 - 0s - loss: 7.9870e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 109/1000
# 2/2 - 0s - loss: 7.9472e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 110/1000
# 2/2 - 0s - loss: 7.9075e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 111/1000
# 2/2 - 0s - loss: 7.8280e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 112/1000
# 2/2 - 0s - loss: 7.7883e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 113/1000
# 2/2 - 0s - loss: 7.7088e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 114/1000
# 2/2 - 0s - loss: 7.6691e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 115/1000
# 2/2 - 0s - loss: 7.5896e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 116/1000
# 2/2 - 0s - loss: 7.4704e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 117/1000
# 2/2 - 0s - loss: 7.3909e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 118/1000
# 2/2 - 0s - loss: 7.3115e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 119/1000
# 2/2 - 0s - loss: 7.2717e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 120/1000
# 2/2 - 0s - loss: 7.2320e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 121/1000
# 2/2 - 0s - loss: 7.1923e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 122/1000
# 2/2 - 0s - loss: 7.1128e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 123/1000
# 2/2 - 0s - loss: 7.0730e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 124/1000
# 2/2 - 0s - loss: 6.9936e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 125/1000
# 2/2 - 0s - loss: 6.9936e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 126/1000
# 2/2 - 0s - loss: 6.9141e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 127/1000
# 2/2 - 0s - loss: 6.8346e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 128/1000
# 2/2 - 0s - loss: 6.8346e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 129/1000
# 2/2 - 0s - loss: 6.7552e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 130/1000
# 2/2 - 0s - loss: 6.6757e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 131/1000
# 2/2 - 0s - loss: 6.6360e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 132/1000
# 2/2 - 0s - loss: 6.6360e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 133/1000
# 2/2 - 0s - loss: 6.5167e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 134/1000
# 2/2 - 0s - loss: 6.5167e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 135/1000
# 2/2 - 0s - loss: 6.4770e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 136/1000
# 2/2 - 0s - loss: 6.4373e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 137/1000
# 2/2 - 0s - loss: 6.3578e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 138/1000
# 2/2 - 0s - loss: 6.2783e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 139/1000
# 2/2 - 0s - loss: 6.2386e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 140/1000
# 2/2 - 0s - loss: 6.2386e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 141/1000
# 2/2 - 0s - loss: 6.1591e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 142/1000
# 2/2 - 0s - loss: 6.1591e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 143/1000
# 2/2 - 0s - loss: 6.0399e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 144/1000
# 2/2 - 0s - loss: 6.0002e-07 - accuracy: 1.0000 - 51ms/epoch - 25ms/step
# Epoch 145/1000
# 2/2 - 0s - loss: 6.0002e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 146/1000
# 2/2 - 0s - loss: 5.9604e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 147/1000
# 2/2 - 0s - loss: 5.9207e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 148/1000
# 2/2 - 0s - loss: 5.8810e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 149/1000
# 2/2 - 0s - loss: 5.8412e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 150/1000
# 2/2 - 0s - loss: 5.8015e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 151/1000
# 2/2 - 0s - loss: 5.7618e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 152/1000
# 2/2 - 0s - loss: 5.7220e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 153/1000
# 2/2 - 0s - loss: 5.7220e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 154/1000
# 2/2 - 0s - loss: 5.6823e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 155/1000
# 2/2 - 0s - loss: 5.6425e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 156/1000
# 2/2 - 0s - loss: 5.6028e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 157/1000
# 2/2 - 0s - loss: 5.6028e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 158/1000
# 2/2 - 0s - loss: 5.5233e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 159/1000
# 2/2 - 0s - loss: 5.4439e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 160/1000
# 2/2 - 0s - loss: 5.3644e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 161/1000
# 2/2 - 0s - loss: 5.3247e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 162/1000
# 2/2 - 0s - loss: 5.3247e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 163/1000
# 2/2 - 0s - loss: 5.2849e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 164/1000
# 2/2 - 0s - loss: 5.2452e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 165/1000
# 2/2 - 0s - loss: 5.2452e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 166/1000
# 2/2 - 0s - loss: 5.2054e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 167/1000
# 2/2 - 0s - loss: 5.2054e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 168/1000
# 2/2 - 0s - loss: 5.1260e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 169/1000
# 2/2 - 0s - loss: 5.0862e-07 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 170/1000
# 2/2 - 0s - loss: 5.0862e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 171/1000
# 2/2 - 0s - loss: 5.0465e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 172/1000
# 2/2 - 0s - loss: 4.9670e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 173/1000
# 2/2 - 0s - loss: 4.9670e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 174/1000
# 2/2 - 0s - loss: 4.9273e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 175/1000
# 2/2 - 0s - loss: 4.8876e-07 - accuracy: 1.0000 - 70ms/epoch - 35ms/step
# Epoch 176/1000
# 2/2 - 0s - loss: 4.8876e-07 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 177/1000
# 2/2 - 0s - loss: 4.7684e-07 - accuracy: 1.0000 - 72ms/epoch - 36ms/step
# Epoch 178/1000
# 2/2 - 0s - loss: 4.7684e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 179/1000
# 2/2 - 0s - loss: 4.7286e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 180/1000
# 2/2 - 0s - loss: 4.7286e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 181/1000
# 2/2 - 0s - loss: 4.6491e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 182/1000
# 2/2 - 0s - loss: 4.6094e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 183/1000
# 2/2 - 0s - loss: 4.5697e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 184/1000
# 2/2 - 0s - loss: 4.5697e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 185/1000
# 2/2 - 0s - loss: 4.5299e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 186/1000
# 2/2 - 0s - loss: 4.4902e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 187/1000
# 2/2 - 0s - loss: 4.4902e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 188/1000
# 2/2 - 0s - loss: 4.4902e-07 - accuracy: 1.0000 - 51ms/epoch - 25ms/step
# Epoch 189/1000
# 2/2 - 0s - loss: 4.4505e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 190/1000
# 2/2 - 0s - loss: 4.4505e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 191/1000
# 2/2 - 0s - loss: 4.4107e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 192/1000
# 2/2 - 0s - loss: 4.4107e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 193/1000
# 2/2 - 0s - loss: 4.3710e-07 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 194/1000
# 2/2 - 0s - loss: 4.2915e-07 - accuracy: 1.0000 - 82ms/epoch - 41ms/step
# Epoch 195/1000
# 2/2 - 0s - loss: 4.2518e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 196/1000
# 2/2 - 0s - loss: 4.2518e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 197/1000
# 2/2 - 0s - loss: 4.2518e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 198/1000
# 2/2 - 0s - loss: 4.2120e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 199/1000
# 2/2 - 0s - loss: 4.1723e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 200/1000
# 2/2 - 0s - loss: 4.1326e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 201/1000
# 2/2 - 0s - loss: 4.1326e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 202/1000
# 2/2 - 0s - loss: 4.0928e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 203/1000
# 2/2 - 0s - loss: 4.0928e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 204/1000
# 2/2 - 0s - loss: 4.0531e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 205/1000
# 2/2 - 0s - loss: 4.0531e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 206/1000
# 2/2 - 0s - loss: 4.0134e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 207/1000
# 2/2 - 0s - loss: 4.0134e-07 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 208/1000
# 2/2 - 0s - loss: 3.9736e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 209/1000
# 2/2 - 0s - loss: 3.9736e-07 - accuracy: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 210/1000
# 2/2 - 0s - loss: 3.9339e-07 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 211/1000
# 2/2 - 0s - loss: 3.8942e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 212/1000
# 2/2 - 0s - loss: 3.8942e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 213/1000
# 2/2 - 0s - loss: 3.8544e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 214/1000
# 2/2 - 0s - loss: 3.8544e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 215/1000
# 2/2 - 0s - loss: 3.8147e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 216/1000
# 2/2 - 0s - loss: 3.8147e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 217/1000
# 2/2 - 0s - loss: 3.8147e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 218/1000
# 2/2 - 0s - loss: 3.7749e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 219/1000
# 2/2 - 0s - loss: 3.7352e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 220/1000
# 2/2 - 0s - loss: 3.6955e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 221/1000
# 2/2 - 0s - loss: 3.6955e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 222/1000
# 2/2 - 0s - loss: 3.6557e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 223/1000
# 2/2 - 0s - loss: 3.6557e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 224/1000
# 2/2 - 0s - loss: 3.6160e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 225/1000
# 2/2 - 0s - loss: 3.6160e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 226/1000
# 2/2 - 0s - loss: 3.5763e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 227/1000
# 2/2 - 0s - loss: 3.5763e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 228/1000
# 2/2 - 0s - loss: 3.4968e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 229/1000
# 2/2 - 0s - loss: 3.4571e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 230/1000
# 2/2 - 0s - loss: 3.4571e-07 - accuracy: 1.0000 - 70ms/epoch - 35ms/step
# Epoch 231/1000
# 2/2 - 0s - loss: 3.4173e-07 - accuracy: 1.0000 - 69ms/epoch - 34ms/step
# Epoch 232/1000
# 2/2 - 0s - loss: 3.4173e-07 - accuracy: 1.0000 - 69ms/epoch - 34ms/step
# Epoch 233/1000
# 2/2 - 0s - loss: 3.3776e-07 - accuracy: 1.0000 - 70ms/epoch - 35ms/step
# Epoch 234/1000
# 2/2 - 0s - loss: 3.3776e-07 - accuracy: 1.0000 - 70ms/epoch - 35ms/step
# Epoch 235/1000
# 2/2 - 0s - loss: 3.3776e-07 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 236/1000
# 2/2 - 0s - loss: 3.3776e-07 - accuracy: 1.0000 - 74ms/epoch - 37ms/step
# Epoch 237/1000
# 2/2 - 0s - loss: 3.3379e-07 - accuracy: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 238/1000
# 2/2 - 0s - loss: 3.3379e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 239/1000
# 2/2 - 0s - loss: 3.2186e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 240/1000
# 2/2 - 0s - loss: 3.2186e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 241/1000
# 2/2 - 0s - loss: 3.2186e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 242/1000
# 2/2 - 0s - loss: 3.1789e-07 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 243/1000
# 2/2 - 0s - loss: 3.1789e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 244/1000
# 2/2 - 0s - loss: 3.1789e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 245/1000
# 2/2 - 0s - loss: 3.1392e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 246/1000
# 2/2 - 0s - loss: 3.1392e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 247/1000
# 2/2 - 0s - loss: 3.1392e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 248/1000
# 2/2 - 0s - loss: 3.0994e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 249/1000
# 2/2 - 0s - loss: 3.0994e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 250/1000
# 2/2 - 0s - loss: 3.0994e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 251/1000
# 2/2 - 0s - loss: 3.0200e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 252/1000
# 2/2 - 0s - loss: 3.0200e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 253/1000
# 2/2 - 0s - loss: 3.0200e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 254/1000
# 2/2 - 0s - loss: 3.0200e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 255/1000
# 2/2 - 0s - loss: 2.9802e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 256/1000
# 2/2 - 0s - loss: 2.9802e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 257/1000
# 2/2 - 0s - loss: 2.9802e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 258/1000
# 2/2 - 0s - loss: 2.9802e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 259/1000
# 2/2 - 0s - loss: 2.9405e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 260/1000
# 2/2 - 0s - loss: 2.9405e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 261/1000
# 2/2 - 0s - loss: 2.9405e-07 - accuracy: 1.0000 - 73ms/epoch - 36ms/step
# Epoch 262/1000
# 2/2 - 0s - loss: 2.9405e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 263/1000
# 2/2 - 0s - loss: 2.9008e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 264/1000
# 2/2 - 0s - loss: 2.9008e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 265/1000
# 2/2 - 0s - loss: 2.8610e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 266/1000
# 2/2 - 0s - loss: 2.8610e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 267/1000
# 2/2 - 0s - loss: 2.8213e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 268/1000
# 2/2 - 0s - loss: 2.7815e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 269/1000
# 2/2 - 0s - loss: 2.7815e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 270/1000
# 2/2 - 0s - loss: 2.7815e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 271/1000
# 2/2 - 0s - loss: 2.7418e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 272/1000
# 2/2 - 0s - loss: 2.7418e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 273/1000
# 2/2 - 0s - loss: 2.7418e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 274/1000
# 2/2 - 0s - loss: 2.7021e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 275/1000
# 2/2 - 0s - loss: 2.7021e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 276/1000
# 2/2 - 0s - loss: 2.7021e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 277/1000
# 2/2 - 0s - loss: 2.6623e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 278/1000
# 2/2 - 0s - loss: 2.6623e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 279/1000
# 2/2 - 0s - loss: 2.6226e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 280/1000
# 2/2 - 0s - loss: 2.6226e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 281/1000
# 2/2 - 0s - loss: 2.6226e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 282/1000
# 2/2 - 0s - loss: 2.6226e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 283/1000
# 2/2 - 0s - loss: 2.5829e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 284/1000
# 2/2 - 0s - loss: 2.5829e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 285/1000
# 2/2 - 0s - loss: 2.5829e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 286/1000
# 2/2 - 0s - loss: 2.5829e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 287/1000
# 2/2 - 0s - loss: 2.5829e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 288/1000
# 2/2 - 0s - loss: 2.5431e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 289/1000
# 2/2 - 0s - loss: 2.5431e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 290/1000
# 2/2 - 0s - loss: 2.5431e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 291/1000
# 2/2 - 0s - loss: 2.5034e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 292/1000
# 2/2 - 0s - loss: 2.5034e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 293/1000
# 2/2 - 0s - loss: 2.4637e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 294/1000
# 2/2 - 0s - loss: 2.4637e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 295/1000
# 2/2 - 0s - loss: 2.4637e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 296/1000
# 2/2 - 0s - loss: 2.4637e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 297/1000
# 2/2 - 0s - loss: 2.4637e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 298/1000
# 2/2 - 0s - loss: 2.4637e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 299/1000
# 2/2 - 0s - loss: 2.4239e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 300/1000
# 2/2 - 0s - loss: 2.4239e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 301/1000
# 2/2 - 0s - loss: 2.4239e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 302/1000
# 2/2 - 0s - loss: 2.4239e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 303/1000
# 2/2 - 0s - loss: 2.4239e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 304/1000
# 2/2 - 0s - loss: 2.3842e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 305/1000
# 2/2 - 0s - loss: 2.3842e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 306/1000
# 2/2 - 0s - loss: 2.3842e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 307/1000
# 2/2 - 0s - loss: 2.3842e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 308/1000
# 2/2 - 0s - loss: 2.3842e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 309/1000
# 2/2 - 0s - loss: 2.3842e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 310/1000
# 2/2 - 0s - loss: 2.3444e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 311/1000
# 2/2 - 0s - loss: 2.3444e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 312/1000
# 2/2 - 0s - loss: 2.3444e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 313/1000
# 2/2 - 0s - loss: 2.3047e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 314/1000
# 2/2 - 0s - loss: 2.3047e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 315/1000
# 2/2 - 0s - loss: 2.2650e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 316/1000
# 2/2 - 0s - loss: 2.2650e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 317/1000
# 2/2 - 0s - loss: 2.2252e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 318/1000
# 2/2 - 0s - loss: 2.2252e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 319/1000
# 2/2 - 0s - loss: 2.1855e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 320/1000
# 2/2 - 0s - loss: 2.1855e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 321/1000
# 2/2 - 0s - loss: 2.1855e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 322/1000
# 2/2 - 0s - loss: 2.1855e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 323/1000
# 2/2 - 0s - loss: 2.1855e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 324/1000
# 2/2 - 0s - loss: 2.1458e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 325/1000
# 2/2 - 0s - loss: 2.1458e-07 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 326/1000
# 2/2 - 0s - loss: 2.1458e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 327/1000
# 2/2 - 0s - loss: 2.1458e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 328/1000
# 2/2 - 0s - loss: 2.1458e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 329/1000
# 2/2 - 0s - loss: 2.1060e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 330/1000
# 2/2 - 0s - loss: 2.1060e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 331/1000
# 2/2 - 0s - loss: 2.1060e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 332/1000
# 2/2 - 0s - loss: 2.1060e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 333/1000
# 2/2 - 0s - loss: 2.1060e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 334/1000
# 2/2 - 0s - loss: 2.0663e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 335/1000
# 2/2 - 0s - loss: 2.0663e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 336/1000
# 2/2 - 0s - loss: 2.0663e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 337/1000
# 2/2 - 0s - loss: 2.0663e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 338/1000
# 2/2 - 0s - loss: 2.0663e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 339/1000
# 2/2 - 0s - loss: 1.9868e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 340/1000
# 2/2 - 0s - loss: 1.9868e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 341/1000
# 2/2 - 0s - loss: 1.9868e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 342/1000
# 2/2 - 0s - loss: 1.9868e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 343/1000
# 2/2 - 0s - loss: 1.9868e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 344/1000
# 2/2 - 0s - loss: 1.9471e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 345/1000
# 2/2 - 0s - loss: 1.9471e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 346/1000
# 2/2 - 0s - loss: 1.9471e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 347/1000
# 2/2 - 0s - loss: 1.9471e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 348/1000
# 2/2 - 0s - loss: 1.9471e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 349/1000
# 2/2 - 0s - loss: 1.9471e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 350/1000
# 2/2 - 0s - loss: 1.9073e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 351/1000
# 2/2 - 0s - loss: 1.9073e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 352/1000
# 2/2 - 0s - loss: 1.9073e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 353/1000
# 2/2 - 0s - loss: 1.9073e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 354/1000
# 2/2 - 0s - loss: 1.9073e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 355/1000
# 2/2 - 0s - loss: 1.9073e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 356/1000
# 2/2 - 0s - loss: 1.8676e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 357/1000
# 2/2 - 0s - loss: 1.8676e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 358/1000
# 2/2 - 0s - loss: 1.8676e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 359/1000
# 2/2 - 0s - loss: 1.8676e-07 - accuracy: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 360/1000
# 2/2 - 0s - loss: 1.8676e-07 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 361/1000
# 2/2 - 0s - loss: 1.8279e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 362/1000
# 2/2 - 0s - loss: 1.8279e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 363/1000
# 2/2 - 0s - loss: 1.8279e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 364/1000
# 2/2 - 0s - loss: 1.8279e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 365/1000
# 2/2 - 0s - loss: 1.8279e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 366/1000
# 2/2 - 0s - loss: 1.8279e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 367/1000
# 2/2 - 0s - loss: 1.7881e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 368/1000
# 2/2 - 0s - loss: 1.7087e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 369/1000
# 2/2 - 0s - loss: 1.7087e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 370/1000
# 2/2 - 0s - loss: 1.7087e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 371/1000
# 2/2 - 0s - loss: 1.7087e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 372/1000
# 2/2 - 0s - loss: 1.7087e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 373/1000
# 2/2 - 0s - loss: 1.7087e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 374/1000
# 2/2 - 0s - loss: 1.6689e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 375/1000
# 2/2 - 0s - loss: 1.6689e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 376/1000
# 2/2 - 0s - loss: 1.6292e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 377/1000
# 2/2 - 0s - loss: 1.6292e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 378/1000
# 2/2 - 0s - loss: 1.6292e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 379/1000
# 2/2 - 0s - loss: 1.6292e-07 - accuracy: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 380/1000
# 2/2 - 0s - loss: 1.5895e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 381/1000
# 2/2 - 0s - loss: 1.5895e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 382/1000
# 2/2 - 0s - loss: 1.5895e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 383/1000
# 2/2 - 0s - loss: 1.5895e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 384/1000
# 2/2 - 0s - loss: 1.5895e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 385/1000
# 2/2 - 0s - loss: 1.5895e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 386/1000
# 2/2 - 0s - loss: 1.5497e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 387/1000
# 2/2 - 0s - loss: 1.5497e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 388/1000
# 2/2 - 0s - loss: 1.5497e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 389/1000
# 2/2 - 0s - loss: 1.5497e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 390/1000
# 2/2 - 0s - loss: 1.5497e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 391/1000
# 2/2 - 0s - loss: 1.5497e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 392/1000
# 2/2 - 0s - loss: 1.5497e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 393/1000
# 2/2 - 0s - loss: 1.5100e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 394/1000
# 2/2 - 0s - loss: 1.5100e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 395/1000
# 2/2 - 0s - loss: 1.5100e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 396/1000
# 2/2 - 0s - loss: 1.5100e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 397/1000
# 2/2 - 0s - loss: 1.5100e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 398/1000
# 2/2 - 0s - loss: 1.5100e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 399/1000
# 2/2 - 0s - loss: 1.5100e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 400/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 401/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 402/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 403/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 404/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 405/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 406/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 407/1000
# 2/2 - 0s - loss: 1.4702e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 408/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 409/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 410/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 411/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 412/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 413/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 414/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 415/1000
# 2/2 - 0s - loss: 1.4305e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 416/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 417/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 418/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 419/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 420/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 421/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 422/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 423/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 424/1000
# 2/2 - 0s - loss: 1.3908e-07 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 425/1000
# 2/2 - 0s - loss: 1.3510e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 426/1000
# 2/2 - 0s - loss: 1.3510e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 427/1000
# 2/2 - 0s - loss: 1.3510e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 428/1000
# 2/2 - 0s - loss: 1.3510e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 429/1000
# 2/2 - 0s - loss: 1.3113e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 430/1000
# 2/2 - 0s - loss: 1.3113e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 431/1000
# 2/2 - 0s - loss: 1.3113e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 432/1000
# 2/2 - 0s - loss: 1.3113e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 433/1000
# 2/2 - 0s - loss: 1.3113e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 434/1000
# 2/2 - 0s - loss: 1.2716e-07 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 435/1000
# 2/2 - 0s - loss: 1.2716e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 436/1000
# 2/2 - 0s - loss: 1.2716e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 437/1000
# 2/2 - 0s - loss: 1.2716e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 438/1000
# 2/2 - 0s - loss: 1.2716e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 439/1000
# 2/2 - 0s - loss: 1.2318e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 440/1000
# 2/2 - 0s - loss: 1.2318e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 441/1000
# 2/2 - 0s - loss: 1.2318e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 442/1000
# 2/2 - 0s - loss: 1.2318e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 443/1000
# 2/2 - 0s - loss: 1.2318e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 444/1000
# 2/2 - 0s - loss: 1.1921e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 445/1000
# 2/2 - 0s - loss: 1.1921e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 446/1000
# 2/2 - 0s - loss: 1.1921e-07 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 447/1000
# 2/2 - 0s - loss: 1.1921e-07 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 448/1000
# 2/2 - 0s - loss: 1.1921e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 449/1000
# 2/2 - 0s - loss: 1.1524e-07 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 450/1000
# 2/2 - 0s - loss: 1.1524e-07 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 451/1000
# 2/2 - 0s - loss: 1.1524e-07 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 452/1000
# 2/2 - 0s - loss: 1.0729e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 453/1000
# 2/2 - 0s - loss: 1.0729e-07 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 454/1000
# 2/2 - 0s - loss: 1.0331e-07 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 455/1000
# 2/2 - 0s - loss: 1.0331e-07 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 456/1000
# 2/2 - 0s - loss: 1.0331e-07 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 457/1000
# 2/2 - 0s - loss: 1.0331e-07 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 458/1000
# 2/2 - 0s - loss: 1.0331e-07 - accuracy: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 459/1000
# 2/2 - 0s - loss: 1.0331e-07 - accuracy: 1.0000 - 71ms/epoch - 35ms/step
# Epoch 460/1000
# 2/2 - 0s - loss: 1.0331e-07 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 461/1000
# 2/2 - 0s - loss: 9.9341e-08 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 462/1000
# 2/2 - 0s - loss: 9.9341e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 463/1000
# 2/2 - 0s - loss: 9.9341e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 464/1000
# 2/2 - 0s - loss: 9.9341e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 465/1000
# 2/2 - 0s - loss: 9.9341e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 466/1000
# 2/2 - 0s - loss: 9.9341e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 467/1000
# 2/2 - 0s - loss: 9.5367e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 468/1000
# 2/2 - 0s - loss: 9.5367e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 469/1000
# 2/2 - 0s - loss: 9.5367e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 470/1000
# 2/2 - 0s - loss: 9.5367e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 471/1000
# 2/2 - 0s - loss: 9.5367e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 472/1000
# 2/2 - 0s - loss: 9.1394e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 473/1000
# 2/2 - 0s - loss: 8.7420e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 474/1000
# 2/2 - 0s - loss: 8.7420e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 475/1000
# 2/2 - 0s - loss: 8.7420e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 476/1000
# 2/2 - 0s - loss: 8.7420e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 477/1000
# 2/2 - 0s - loss: 8.7420e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 478/1000
# 2/2 - 0s - loss: 8.7420e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 479/1000
# 2/2 - 0s - loss: 8.7420e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 480/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 481/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 482/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 483/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 484/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 485/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 486/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 487/1000
# 2/2 - 0s - loss: 8.3446e-08 - accuracy: 1.0000 - 51ms/epoch - 25ms/step
# Epoch 488/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 489/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 490/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 491/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 492/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 493/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 494/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 495/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 496/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 497/1000
# 2/2 - 0s - loss: 7.9473e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 498/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 499/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 500/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 501/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 502/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 503/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 504/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 505/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 506/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 507/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 508/1000
# 2/2 - 0s - loss: 7.5499e-08 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 509/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 510/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 511/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 512/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 513/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 514/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 515/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 516/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 517/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 518/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 519/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 520/1000
# 2/2 - 0s - loss: 7.1526e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 521/1000
# 2/2 - 0s - loss: 6.7552e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 522/1000
# 2/2 - 0s - loss: 6.7552e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 523/1000
# 2/2 - 0s - loss: 6.7552e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 524/1000
# 2/2 - 0s - loss: 6.7552e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 525/1000
# 2/2 - 0s - loss: 6.7552e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 526/1000
# 2/2 - 0s - loss: 6.7552e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 527/1000
# 2/2 - 0s - loss: 6.7552e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 528/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 529/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 530/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 531/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 532/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 533/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 534/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 535/1000
# 2/2 - 0s - loss: 6.3578e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 536/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 537/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 538/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 539/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 540/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 541/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 542/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 543/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 544/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 545/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 546/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 51ms/epoch - 25ms/step
# Epoch 547/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 548/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 549/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 550/1000
# 2/2 - 0s - loss: 5.9605e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 551/1000
# 2/2 - 0s - loss: 5.5631e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 552/1000
# 2/2 - 0s - loss: 5.5631e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 553/1000
# 2/2 - 0s - loss: 5.5631e-08 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 554/1000
# 2/2 - 0s - loss: 5.5631e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# ...
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 818/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 819/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 820/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 821/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 822/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 823/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 824/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 825/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 826/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 827/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 828/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 829/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 830/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 831/1000
# 2/2 - 0s - loss: 2.3842e-08 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 832/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 833/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 834/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 71ms/epoch - 35ms/step
# Epoch 835/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 836/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 837/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 838/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 839/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 840/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 841/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 842/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 843/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 844/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 845/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 846/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 847/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 848/1000
# 2/2 - 0s - loss: 1.9868e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 849/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 850/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 851/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 852/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 853/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 854/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 855/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 856/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 857/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 858/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 859/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 860/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 861/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 862/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 863/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 864/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 865/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 866/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 867/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 868/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 869/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 870/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 871/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 65ms/epoch - 32ms/step
# Epoch 872/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 873/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 874/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 875/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 876/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 877/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 878/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 879/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 880/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 881/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 882/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 883/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 884/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 885/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 886/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 887/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 888/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 889/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 890/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 891/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 892/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 893/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 894/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 895/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 896/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 897/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 898/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 899/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 900/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 901/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 902/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 903/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 904/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 905/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 906/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 907/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 908/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 909/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 910/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 911/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 912/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 913/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 914/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 915/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 916/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 917/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 918/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 919/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 920/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 921/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 922/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 923/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 924/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 925/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 926/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 927/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 928/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 929/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 930/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 931/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 932/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 933/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 934/1000
# 2/2 - 0s - loss: 1.5895e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 935/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 936/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 937/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 938/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 939/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 940/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 941/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 942/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 943/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 944/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 945/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 946/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 947/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 948/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 949/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 950/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 951/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 952/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 953/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 954/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 955/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 956/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 957/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 958/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 959/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 960/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 961/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 962/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 963/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 964/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 965/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 966/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 967/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 968/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 969/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 970/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 971/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 972/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 973/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 974/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 975/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 976/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 977/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 978/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 979/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 53ms/epoch - 26ms/step
# Epoch 980/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 981/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 982/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 983/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 984/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 985/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 986/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 987/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 988/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 989/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 59ms/epoch - 29ms/step
# Epoch 990/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 991/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 60ms/epoch - 30ms/step
# Epoch 992/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 993/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 994/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 995/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 58ms/epoch - 29ms/step
# Epoch 996/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 63ms/epoch - 31ms/step
# Epoch 997/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 998/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step
# Epoch 999/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 1000/1000
# 2/2 - 0s - loss: 1.1921e-08 - accuracy: 1.0000 - 54ms/epoch - 27ms/step

# %% [markdown]
# Epoch 1000/1000
#
# loss: 2.7510e-08 - accuracy: 1.0000
#
# loss: 1.1921e-08
#
# loss is low
# 100% accuracy

# %%
# handle the test dataset ( images)
print("Testing the neural network....")

test_pixel_intensities = []

test_image1 = Image.open('test_set/happy_test1.png').convert('1') # we have to transform the image into 1D numpy array as far
                                                                # as the pixel intensities are concerned
test_pixel_intensities.append(list(test_image1.getdata())) # (list(test_image1.getdata())
                                            # we get the pixel intensities, we transform it into a list
                                            # and then we all did as the first item in 1D array
                                            # test_pixel_intensities = []
            
# we have to normalize the data again

test_pixel_intensities = np.array(test_pixel_intensities)/255

print(model.predict(test_pixel_intensities).round())
# Out:
# Testing the neural network....
# 1/1 [==============================] - 0s 104ms/step
# [[1. 0.]]
